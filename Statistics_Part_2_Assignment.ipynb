# %% [markdown]
# # Assignment Questions

# %% [markdown]
# **1.What is hypothesis testing in statistics?**
#
# ans-Hypothesis testing is a statistical method used to make decisions or inferences about a population based on sample data. It involves formulating a hypothesis, collecting data, and using statistical techniques to determine whether there is enough evidence to support or reject the hypothesis.
#
# **Key Steps in Hypothesis Testing:**
#
# - Formulate Hypotheses- Null Hypothesis (H₀): Assumes there is no effect or difference.
# - Alternative Hypothesis (H₁): Suggests there is an effect or difference.
#
# - Choose a Significance Level (α)- Common values are 0.05 or 0.01, which indicate the probability of rejecting the null hypothesis when it is actually true.
#
# - Select a Test Statistic- Examples: Z-test, T-test, Chi-square test, ANOVA, etc.
#
# - Compute the Test Statistic & P-value- The p-value helps determine the strength of the evidence against H₀.
#
# - Make a Decision- If the p-value is less than α, reject H₀ (suggests evidence for H₁).
# - If the p-value is greater than α, fail to reject H₀ (not enough evidence for H₁).

# %% [markdown]
# **2.What is the null hypothesis, and how does it differ from the alternative hypothesis?**
#
# ans-The null hypothesis (H₀) and alternative hypothesis (H₁) are the two core components of hypothesis testing in statistics.
#
# **Null Hypothesis (H₀):**
# This hypothesis states that there is no effect, difference, or relationship between variables. It represents the default assumption, meaning that any observed results are due to chance.
# - Example: A new teaching method does not improve student test scores.
#
# **Alternative Hypothesis (H₁):**
# This hypothesis contradicts the null hypothesis and suggests that there is an effect, difference, or relationship between variables.
# - Example: A new teaching method significantly improves student test scores.

# %% [markdown]
# **3.What is the significance level in hypothesis testing, and why is it important?**
#
# ans-The significance level (α) in hypothesis testing is the probability of rejecting the null hypothesis (H₀) when it is actually true. It acts as a threshold to determine whether the observed result is statistically significant.
#
# **Why Is It Important?**
#
# - Controls Type I Error: It helps limit the chance of mistakenly rejecting H₀ when it is actually correct.
# - Establishes Confidence: A lower α (e.g., 0.01) makes the test more stringent, requiring stronger evidence to reject H₀.
# - Influences Decision-Making: The significance level helps researchers determine the reliability of their findings.

# %% [markdown]
# **4.What does a P-value represent in hypothesis testing?**
#
# ans-In hypothesis testing, the p-value measures the strength of evidence against the null hypothesis (H₀). It helps determine whether the observed data is statistically significant.
#
# **What Does the P-Value Represent?**
#
# - The p-value is the probability of obtaining results at least as extreme as the observed data, assuming that H₀ is true.
# - A small p-value (typically ≤ α) suggests strong evidence against H₀, leading to its rejection.
# - A large p-value means there is not enough evidence to reject H₀.

# %% [markdown]
# **5.How do you interpret the P-value in hypothesis testing?**
#
# ans-Interpreting the p-value in hypothesis testing helps determine whether we have enough statistical evidence to reject the null hypothesis (H₀).
#
# **How to Interpret the P-Value**
# - The p-value represents the probability of obtaining results as extreme as the observed data, assuming H₀ is true.
# - Smaller p-values suggest stronger evidence against H₀, increasing confidence in rejecting it.
# - Larger p-values indicate weaker evidence against H₀, meaning we fail to reject it.

# %% [markdown]
# **6.What are Type 1 and Type 2 errors in hypothesis testing?**
#
# ans-Type 1 and Type 2 errors are fundamental concepts in hypothesis testing that describe mistakes in decision-making:
#
# * Type 1 Error (False Positive): This occurs when you reject the null hypothesis when it is actually true. In simpler terms, it's like convicting an innocent person in court. The probability of making this error is denoted by α (alpha), which represents the significance level.
#
# * Type 2 Error (False Negative): This happens when you fail to reject the null hypothesis when it is actually false. Think of it as letting a guilty person go free. The probability of making this error is denoted by β (beta).
#
# Balancing these errors is key in statistical analysis. Reducing the likelihood of a Type 1 error usually increases the risk of a Type 2 error, and vice versa. The choice depends on the context—whether avoiding false positives or false negatives is more critical.

# %% [markdown]
# **7.What is the difference between a one-tailed and a two-tailed test in hypothesis testing?**
#
# ans-In hypothesis testing, the difference between a one-tailed and two-tailed test lies in how you assess the direction of the effect:
#
# * One-Tailed Test: You use this when you're testing for an effect in a specific direction—either greater than or less than a certain value. For example, if a manufacturer claims their battery lasts more than 10 hours, a one-tailed test would examine whether the mean lifespan is significantly greater than 10 hours.
#
# * Two-Tailed Test: This tests for any significant difference, regardless of direction. You're looking to see if a value is either higher or lower than expected. For example, if a researcher wants to check whether a drug affects blood pressure in any way (increase or decrease), they would use a two-tailed test.

# %% [markdown]
# **8.What is the Z-test, and when is it used in hypothesis testing?**
#
# ans- The Z-test is a statistical test used to determine whether the mean of a dataset differs significantly from a known population mean. It relies on the Z-score, which measures how far a sample’s mean is from the population mean in terms of standard deviations.
#
# **When is the Z-test used?**
# The Z-test is appropriate when:
#
# * Sample size is large (n ≥ 30) or the population follows a normal distribution.
#
# * Population standard deviation (σ) is known (unlike the t-test, which is used when σ is unknown).
#
# * You're testing hypotheses for a single mean or comparing two means.

# %% [markdown]
# **9.How do you calculate the Z-score, and what does it represent in hypothesis testing?**
#
# ans-The Z-score, or standard score, measures how far a data point or sample mean deviates from the population mean in terms of standard deviations. It helps determine whether an observed result is significantly different from what we expect under the null hypothesis.
#
# **Formula for Z-score:**
# 𝑍
# =
# 𝑋
# /
# 𝜇
# 𝜎
#
# Where:
#
# X = Sample value (or sample mean in hypothesis testing)
#
# μ = Population mean
#
# σ = Population standard deviation
#
# **What does the Z-score represent?**
# * Positive Z-score: The value is above the mean.
#
# * Negative Z-score: The value is below the mean.
#
# * Z = 0: The value is equal to the mean.
#
# * Larger absolute Z-values indicate greater deviation, making it more likely that the result is statistically significant.

# %% [markdown]
# **10.What is the T-distribution, and when should it be used instead of the normal distribution?**
#
# ans- The T-distribution, also known as Student’s t-distribution, is a probability distribution that accounts for uncertainty when working with small sample sizes. It is similar to the normal distribution but has fatter tails, meaning it reflects more variability.
#
# **When should you use the T-distribution instead of the normal distribution?**
#
# 1. Small Sample Size (
# 𝑛
# <
# 30
# ): When the sample size is small, the normal distribution may not be accurate, and the t-distribution provides better estimates.
#
# 2. Unknown Population Standard Deviation (
# 𝜎
# ): If the population standard deviation is unknown, you estimate it using the sample standard deviation and use the t-distribution instead of the normal distribution.
#
# 3. Approximating a Normal Distribution with Greater Uncertainty: Since the t-distribution has heavier tails, it accounts for the increased variability in small samples.

# %% [markdown]
# **11.What is the difference between a Z-test and a T-test?**
#
# ans-Great question! Both Z-tests and T-tests are used in hypothesis testing, but they differ in their application based on sample size and population variance.
#
# Z-test:
# - Used when the sample size is large (n ≥ 30).
# - Assumes the population standard deviation is known.
# - Based on the normal distribution.
# - Generally applied for comparing means when the data follows a normal distribution.
#
# T-test:
# - Used when the sample size is small (n < 30).
# - Assumes the population standard deviation is unknown, so we estimate it from the sample.
# - Based on the t-distribution, which has thicker tails than a normal distribution (making it more conservative).
# - Useful for comparing means when dealing with smaller datasets.

# %% [markdown]
# **12.What is the T-test, and how is it used in hypothesis testing?**
#
# ans-The T-test is a statistical test used in hypothesis testing to determine whether there is a significant difference between the means of two groups. It is especially useful when dealing with small sample sizes and when the population standard deviation is unknown.
#
# **Types of T-tests**
#
# * One-Sample T-Test: Compares the mean of a single sample to a known population mean.
#
# * Two-Sample T-Test (Independent T-Test): Compares the means of two independent groups to determine if they are significantly different.
#
# * Paired T-Test: Used when comparing the means of two related groups, such as before-and-after measurements in an experiment.

# %% [markdown]
# **13.What is the relationship between Z-test and T-test in hypothesis testing?**
#
# ans-The Z-test and T-test are closely related statistical tools used for hypothesis testing, but they differ based on sample size and data assumptions. Think of them as siblings—similar in purpose but adapted for different situations.
#
# **Key Relationship Between Z-test and T-test:**
# * Both are used to test population means and determine if differences are statistically significant.
#
# * Both use similar formulas, but the Z-test relies on the known population standard deviation (
# 𝜎
# ), while the T-test substitutes it with the sample standard deviation (
# 𝑠
# ).
#
# * As sample size increases (
# 𝑛
# ≥
# 30
# ), the T-distribution approaches the normal distribution, making the results of a T-test and Z-test nearly identical for large samples.
#
# * T-test is more flexible and can handle smaller samples and unknown population standard deviations, while the Z-test is more rigid and relies on larger datasets.

# %% [markdown]
# **14.What is a confidence interval, and how is it used to interpret statistical results?**
#
# ans-A confidence interval (CI) is a range of values used to estimate an unknown population parameter, such as a mean or proportion, based on sample data. It provides a margin of error around an estimate and indicates the level of certainty about the result.
#
# **Key Components of a Confidence Interval**
# * Point Estimate: The sample statistic (e.g., sample mean) used as the best guess for the population parameter.
#
# * Margin of Error: Accounts for sampling variability and is influenced by the confidence level and sample size.
#
# * Confidence Level: The probability that the true population parameter lies within the interval. Common levels are 90%, 95%, or 99%.

# %% [markdown]
# **15.What is the margin of error, and how does it affect the confidence interval?**
#
# ans-The margin of error (MOE) represents the range within which the true population parameter is expected to lie, given a sample. It's crucial in statistical estimates, particularly confidence intervals.
#
# **How It Works:**
# The margin of error is calculated as:
# [ MOE = Z \times \frac{\sigma}{\sqrt{n}} ]
# Where:
# - Z is the Z-score (based on confidence level, e.g., 1.96 for 95% confidence).
# - σ is the population standard deviation.
# - n is the sample size.
#
# **Impact on Confidence Interval:**
# A confidence interval is given by:
# [ \text{Sample Estimate} \pm \text{Margin of Error} ]
# - A larger MOE means a wider confidence interval, indicating more uncertainty.
# - A smaller MOE results in a narrower confidence interval, meaning a more precise estimate.
#
# Factors influencing MOE include:
# - Sample Size (n): Larger samples reduce the margin of error.
# - Confidence Level: Higher confidence levels increase MOE.
# - Population Variability (σ): More variability leads to a larger MOE.

# %% [markdown]
# **16.How is Bayes' Theorem used in statistics, and what is its significance?**
#
# ans-
#
# **How It's Used in Statistics:**
# - Medical Diagnosis: Doctors use Bayes' Theorem to determine the probability of a disease given test results.
# - Spam Filtering: Email providers use Bayesian filtering to classify emails as spam or legitimate based on keywords.
# - Machine Learning: Bayesian inference helps update model parameters based on new data.
# - Risk Assessment: Financial analysts use it to refine risk predictions for investments.
#
# **Significance:**
# - Allows Learning from Data: It lets statisticians refine predictions as more information becomes available.
# - Handles Uncertainty: Unlike classical probability, it incorporates prior knowledge, making it useful in real-world applications.
# - Forms the Basis for Bayesian Statistics: A major branch of statistics focused on probabilistic reasoning and decision-making.

# %% [markdown]
# **17.What is the Chi-square distribution, and when is it used?**
#
# ans-The Chi-square distribution is a probability distribution used in statistics to test hypotheses about categorical data. It arises when summing the squares of independent standard normal variables.
#
# **Key Characteristics:**
# - Right-skewed, especially with small degrees of freedom (df).
# - Defined only for non-negative values (starts at 0 and extends to infinity).
# - Degrees of Freedom (df) determine its shape—the higher the df, the more it resembles a normal distribution.
#
# **When Is It Used?**
#
# The Chi-square distribution is primarily used in statistical tests involving categorical data, such as:
# - Chi-square Goodness-of-Fit Test: Checks if observed data fits an expected distribution.
# - Chi-square Test for Independence: Determines if two categorical variables are related (e.g., does smoking influence heart disease?).
# - Chi-square Test for Homogeneity: Compares distributions across multiple groups.
# - Variance Estimation in Normal Samples: Used in confidence interval calculations for variance.

# %% [markdown]
# **18.What is the Chi-square goodness of fit test, and how is it applied?**
#
# ans-The Chi-square goodness-of-fit test is a statistical method used to determine whether observed data fits a specific expected distribution. It helps us assess whether discrepancies between observed and expected frequencies are due to random chance or a significant pattern.
# Application Steps:
# - Define Hypotheses:- Null Hypothesis (H₀): The observed data follows the expected distribution.
# - Alternative Hypothesis (H₁): The observed data differs significantly from the expected distribution.
#
# - Calculate Expected Frequencies:- Based on theoretical proportions or previous data.
#
# - Compute the Chi-square Statistic:- Using the formula above.
#
# - Determine Degrees of Freedom (df):- ( df = \text{number of categories} - 1 ).
#
# - Compare with Critical Value or P-value:- If the Chi-square statistic is greater than the critical value (or if the p-value is less than the significance level, typically 0.05), we reject H₀.

# %% [markdown]
# **19.What is the F-distribution, and when is it used in hypothesis testing?**
#
# ans-The F-distribution is a probability distribution used in statistics, primarily in hypothesis testing involving variance comparisons. It is derived from the ratio of two independent chi-square distributed variables and is always non-negative and right-skewed.
#
# **Key Properties:**
# - Defined only for positive values (starts at 0).
# - Shape depends on two degrees of freedom (df₁, df₂).
# - As degrees of freedom increase, it approaches a normal distribution.
#
# **When Is It Used?**
#
# The F-distribution is commonly used in tests involving variance and regression analysis, such as:
# - ANOVA (Analysis of Variance):- Determines if multiple group means differ significantly.
# - Compares within-group variance to between-group variance.
#
# - F-Test for Equality of Variances:- Compares the variance of two populations.
# - Tests whether two datasets have similar variability.
#
# - Regression Analysis:- Evaluates the overall significance of a regression model.
# - Tests if the independent variables explain variability in the dependent variable.

# %% [markdown]
# **20.What is an ANOVA test, and what are its assumptions?**
#
# ans-ANOVA (Analysis of Variance) Test
# ANOVA is a statistical method used to compare the means of multiple groups to determine if they are significantly different from one another. Instead of comparing groups pairwise (like with t-tests), ANOVA evaluates variability between and within groups simultaneously.
#
# **Types of ANOVA:**
# - One-Way ANOVA: Used when comparing means of one independent variable across multiple groups.
# - Two-Way ANOVA: Used when analyzing two independent variables and their interactions.
#
# **Assumptions of ANOVA:**
# To ensure reliable results, ANOVA relies on the following assumptions:
# - Independence: Observations must be independent of one another.
# - Normality: Each group’s data should follow a normal distribution.
# - Homogeneity of Variance (Homoscedasticity): The variances of the different groups should be approximately equal.
# - Random Sampling: Data should be collected using random sampling methods.
# - Continuous Data: The dependent variable should be measured on a continuous scale.

# %% [markdown]
# **21.What are the different types of ANOVA tests?**
#
# ans-ANOVA (Analysis of Variance) comes in different types depending on the number of independent variables and the complexity of the study. Here are the main types:
# 1. One-Way ANOVA
# - Used to compare the means of three or more groups based on one independent variable.
# - Example: Comparing the test scores of students across three different schools.
#
# 2. Two-Way ANOVA
# - Used when there are two independent variables and their possible interaction effects.
# - Example: Studying how diet (A) and exercise level (B) affect body weight.
#
# 3. Repeated Measures ANOVA
# - Used when the same subjects are measured multiple times under different conditions.
# - Example: Tracking cognitive performance before, during, and after a new training program.
#
# 4. MANOVA (Multivariate ANOVA)
# - Extends ANOVA to multiple dependent variables instead of just one.
# - Example: Analyzing sales revenue and customer satisfaction across multiple stores.
#
# 5. ANCOVA (Analysis of Covariance)
# - A modification of ANOVA that controls for a covariate, a variable that might influence the outcome.
# - Example: Studying how marketing strategies impact sales, while adjusting for store location.

# %% [markdown]
# **22.What is the F-test, and how does it relate to hypothesis testing?**
#
# ans-F-Test and Its Role in Hypothesis Testing
# An F-test is a statistical test used to compare variances or regression models. It evaluates whether the variability between groups is significantly different, helping in various hypothesis testing scenarios.
#
# **Common Uses of the F-Test in Hypothesis Testing:**
# - Equality of Two Variances- Tests whether two populations have the same variance.
# - Used before applying certain statistical methods like t-tests (since t-tests assume equal variances).
#
# - ANOVA (Analysis of Variance)- Compares means across multiple groups.
# - Helps determine if variations between groups are greater than variations within groups.
#
# - Regression Analysis- Assesses the overall significance of a regression model.
# - Determines if independent variables significantly influence the dependent variable.

# %% [markdown]
# # Practical Part - 1

# %% [markdown]
# **1.Write a Python program to generate a random variable and display its value**

# %%
import random

# Generate a random floating-point number between 0 and 1
random_value = random.random()

# Display the generated random value
print("Generated random value:", random_value)
# Out:
# Generated random value: 0.1997161208658378

# %% [markdown]
# **2.Generate a discrete uniform distribution using Python and plot the probability mass function (PMF)**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define possible values
x = np.arange(1, 11)  # Values from 1 to 10
pmf_values = np.ones_like(x) / len(x)  # Equal probability for each value

# Plot the PMF
plt.bar(x, pmf_values, color='skyblue', edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Probability')
plt.title('PMF of Discrete Uniform Distribution')
plt.xticks(x)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# **3.Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution**

# %%
import numpy as np
import matplotlib.pyplot as plt

def bernoulli_pdf(p):
    """Calculate and visualize the probability distribution function (PDF) of a Bernoulli distribution."""
    x = np.array([0, 1])  # Possible outcomes (0 = failure, 1 = success)
    pdf_values = np.array([1 - p, p])  # Probability mass function (PMF)

    # Plot the Bernoulli distribution
    plt.bar(x, pdf_values, color='skyblue', edgecolor='black', alpha=0.7)
    plt.xticks(x, labels=['Failure (0)', 'Success (1)'])
    plt.xlabel('Outcome')
    plt.ylabel('Probability')
    plt.title(f'Bernoulli Distribution (p={p})')
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# Example usage
bernoulli_pdf(0.7)  # Assuming probability of success p = 0.7

# %% [markdown]
# **4.Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
n = 10  # Number of trials
p = 0.5  # Probability of success
size = 1000  # Number of simulations

# Generate binomial distribution samples
samples = np.random.binomial(n, p, size)

# Plot histogram
plt.hist(samples, bins=range(n+2), density=True, alpha=0.7, color='skyblue', edgecolor='black')
plt.xlabel('Number of successes')
plt.ylabel('Probability')
plt.title(f'Binomial Distribution (n={n}, p={p})')
plt.xticks(range(n+1))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# **5.Create a Poisson distribution and visualize it using Python**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define Poisson distribution parameters
lambda_value = 5  # Average number of occurrences
size = 1000  # Number of samples

# Generate Poisson-distributed samples
samples = np.random.poisson(lambda_value, size)

# Plot histogram
plt.hist(samples, bins=range(0, max(samples) + 2), density=True, color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel('Number of occurrences')
plt.ylabel('Probability')
plt.title(f'Poisson Distribution (λ={lambda_value})')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# **6.Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete
# uniform distribution**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the range of values
x = np.arange(1, 11)  # Values from 1 to 10
cdf_values = np.cumsum(np.ones_like(x) / len(x))  # CDF calculation

# Plot the CDF
plt.step(x, cdf_values, where='mid', color='skyblue', linewidth=2, label='CDF')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.title('Cumulative Distribution Function (CDF) of Discrete Uniform Distribution')
plt.xticks(x)
plt.yticks(np.linspace(0, 1, len(x)))
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.show()

# %% [markdown]
# **7.Generate a continuous uniform distribution using NumPy and visualize it**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate uniform distribution samples
samples = np.random.uniform(0, 1, 1000)  # Values between 0 and 1

# Plot histogram
plt.hist(samples, bins=30, density=True, color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Continuous Uniform Distribution (0,1)')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# **8. Simulate data from a normal distribution and plot its histogram**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define normal distribution parameters
mean = 0  # Mean of the distribution
std_dev = 1  # Standard deviation
size = 1000  # Number of samples

# Generate normal distribution samples
samples = np.random.normal(mean, std_dev, size)

# Plot histogram
plt.hist(samples, bins=30, density=True, color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Normal Distribution (Mean=0, Std Dev=1)')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# **9.Write a Python function to calculate Z-scores from a dataset and plot them**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Sample dataset
data = np.random.normal(50, 10, 1000)  # Mean=50, Std Dev=10

# Compute Z-scores
z_scores = (data - np.mean(data)) / np.std(data)

# Plot histogram
plt.hist(z_scores, bins=30, density=True, color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel('Z-score')
plt.ylabel('Density')
plt.title('Histogram of Z-scores')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# **10. Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate sample means from an exponential distribution
sample_means = [np.mean(np.random.exponential(scale=1, size=30)) for _ in range(1000)]

# Plot histogram
plt.hist(sample_means, bins=30, density=True, color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel('Sample Mean')
plt.ylabel('Density')
plt.title('Central Limit Theorem Demonstration')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# **11.Simulate multiple samples from a normal distribution and verify the Central Limit Theorem**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define normal distribution parameters
mean = 50  # Mean of the original distribution
std_dev = 15  # Standard deviation
sample_size = 30  # Size of each sample
num_samples = 1000  # Number of samples

# Generate sample means from the normal distribution
sample_means = [np.mean(np.random.normal(mean, std_dev, sample_size)) for i in range(num_samples)]

# Plot histogram of sample means
plt.hist(sample_means, bins=30, density=True, color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel('Sample Mean')
plt.ylabel('Density')
plt.title('Central Limit Theorem Verification (Normal Distribution)')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# **12.Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1)**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal():
    """Generate and plot the standard normal distribution (mean=0, std=1)."""
    x = np.linspace(-4, 4, 1000)  # Range of values
    pdf_values = norm.pdf(x, 0, 1)  # Probability density function

    # Plot the distribution
    plt.plot(x, pdf_values, color='skyblue', linewidth=2, label='Standard Normal Distribution')
    plt.xlabel('Value')
    plt.ylabel('Probability Density')
    plt.title('Standard Normal Distribution (Mean=0, Std Dev=1)')
    plt.grid(linestyle='--', alpha=0.7)
    plt.legend()
    plt.show()

# Call the function
plot_standard_normal()

# %% [markdown]
# **13.Generate random variables and calculate their corresponding probabilities using the binomial distribution**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

# Define binomial distribution parameters
n = 10  # Number of trials
p = 0.5  # Probability of success
size = 1000  # Number of random variables

# Generate random binomial samples
samples = np.random.binomial(n, p, size)

# Calculate probabilities using the binomial PMF
x = np.arange(n + 1)  # Possible values (0 to n)
pmf_values = binom.pmf(x, n, p)

# Plot histogram of generated samples
plt.hist(samples, bins=range(n + 2), density=True, alpha=0.7, color='skyblue', edgecolor='black', label='Simulated Data')

# Overlay the theoretical binomial PMF
plt.scatter(x, pmf_values, color='red', marker='o', label='Binomial PMF')

plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.title(f'Binomial Distribution (n={n}, p={p})')
plt.xticks(range(n + 1))
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# **14.Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal
# distribution**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def calculate_z_score(value, data):
    """Calculate Z-score for a given value based on dataset statistics."""
    mean = np.mean(data)
    std_dev = np.std(data)
    return (value - mean) / std_dev

# Sample dataset (normally distributed)
data = np.random.normal(50, 10, 1000)  # Mean=50, Std Dev=10
value = 60  # Data point to analyze

# Compute Z-score
z_score = calculate_z_score(value, data)
print(f"Z-score of {value}: {z_score:.2f}")

# Plot standard normal distribution
x = np.linspace(-4, 4, 1000)
pdf_values = norm.pdf(x, 0, 1)

plt.plot(x, pdf_values, color='skyblue', linewidth=2, label='Standard Normal Distribution')
plt.axvline(z_score, color='red', linestyle='--', label=f'Z-score of {value}')
plt.xlabel('Z-score')
plt.ylabel('Probability Density')
plt.title('Standard Normal Distribution with Highlighted Z-score')
plt.legend()
plt.grid(linestyle='--', alpha=0.7)
plt.show()
# Out:
# Z-score of 60: 1.00

# %% [markdown]
# **15.Implement hypothesis testing using Z-statistics for a sample dataset**

# %%
import numpy as np
from scipy.stats import norm

# Sample dataset
data = np.random.normal(50, 10, 30)  # Mean=50, Std Dev=10, Sample size=30

# Hypothesis parameters
population_mean = 52  # Hypothesized mean
sample_mean = np.mean(data)
sample_std_dev = np.std(data, ddof=1)  # Sample standard deviation
n = len(data)

# Calculate Z-score
z_score = (sample_mean - population_mean) / (sample_std_dev / np.sqrt(n))

# Calculate p-value
p_value = 2 * (1 - norm.cdf(abs(z_score)))  # Two-tailed test

# Output results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"Z-score: {z_score:.2f}")
print(f"P-value: {p_value:.5f}")

# Decision
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis: There is enough evidence to support the alternative hypothesis.")
else:
    print("Fail to reject the null hypothesis: Not enough evidence to support the alternative hypothesis.")

# %% [markdown]
# **16.Create a confidence interval for a dataset using Python and interpret the result**

# %%
import numpy as np
import scipy.stats as stats

# Sample dataset
data = np.random.normal(50, 10, 30)  # Mean=50, Std Dev=10, Sample size=30

# Calculate sample statistics
sample_mean = np.mean(data)
sample_std_dev = np.std(data, ddof=1)  # Unbiased standard deviation
n = len(data)

# Define confidence level
confidence_level = 0.95
alpha = 1 - confidence_level

# Calculate margin of error using t-distribution
t_critical = stats.t.ppf(1 - alpha/2, df=n-1)  # Critical value
margin_of_error = t_critical * (sample_std_dev / np.sqrt(n))

# Compute confidence interval
lower_bound = sample_mean - margin_of_error
upper_bound = sample_mean + margin_of_error

# Display results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"Confidence Interval ({confidence_level*100}%): ({lower_bound:.2f}, {upper_bound:.2f})")
# Out:
# Sample Mean: 51.16
# Confidence Interval (95.0%): (47.41, 54.92)

# %% [markdown]
# **17.Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean**

# %%
import numpy as np
import scipy.stats as stats

# Generate normal distribution data
data = np.random.normal(loc=50, scale=10, size=30)  # Mean=50, Std Dev=10, Sample size=30

# Calculate sample statistics
sample_mean = np.mean(data)
sample_std_dev = np.std(data, ddof=1)  # Unbiased standard deviation
n = len(data)

# Confidence level
confidence_level = 0.95
alpha = 1 - confidence_level

# Compute margin of error using t-distribution (for small sample sizes)
t_critical = stats.t.ppf(1 - alpha/2, df=n-1)  # Critical value
margin_of_error = t_critical * (sample_std_dev / np.sqrt(n))

# Confidence interval
lower_bound = sample_mean - margin_of_error
upper_bound = sample_mean + margin_of_error

# Output results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"Confidence Interval ({confidence_level*100}%): ({lower_bound:.2f}, {upper_bound:.2f})")
# Out:
# Sample Mean: 52.21
# Confidence Interval (95.0%): (49.19, 55.23)

# %% [markdown]
# **18.Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Define parameters for the normal distribution
mean = 0  # Mean of the distribution
std_dev = 1  # Standard deviation

# Generate x values
x = np.linspace(-4, 4, 1000)

# Compute PDF values
pdf_values = norm.pdf(x, mean, std_dev)

# Plot the PDF
plt.plot(x, pdf_values, color='skyblue', linewidth=2, label='Normal Distribution PDF')
plt.xlabel('Value')
plt.ylabel('Probability Density')
plt.title('Probability Density Function (PDF) of Normal Distribution')
plt.grid(linestyle='--', alpha=0.7)
plt.legend()
plt.show()

# %% [markdown]
# **19.Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Define Poisson distribution parameters
lambda_value = 5  # Average number of occurrences

# Generate possible values
x = np.arange(0, 15)  # Poisson values from 0 to 14

# Compute CDF values
cdf_values = poisson.cdf(x, lambda_value)

# Plot the CDF
plt.step(x, cdf_values, where='mid', color='skyblue', linewidth=2, label='Poisson CDF')
plt.xlabel('Number of occurrences')
plt.ylabel('Cumulative Probability')
plt.title('Cumulative Distribution Function (CDF) of Poisson Distribution')
plt.xticks(x)
plt.grid(linestyle='--', alpha=0.7)
plt.legend()
plt.show()

# %% [markdown]
# **20.Simulate a random variable using a continuous uniform distribution and calculate its expected value**

# %%
import numpy as np

# Define uniform distribution range
a, b = 0, 10  # Lower and upper bounds

# Generate a random variable from the uniform distribution
random_variable = np.random.uniform(a, b)

# Calculate expected value (E[X] = (a + b) / 2)
expected_value = (a + b) / 2

# Output results
print(f"Generated random variable: {random_variable:.2f}")
print(f"Expected value of the distribution: {expected_value:.2f}")
# Out:
# Generated random variable: 5.32
# Expected value of the distribution: 5.00

# %% [markdown]
# **21.Write a Python program to compare the standard deviations of two datasets and visualize the difference**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate two datasets with different standard deviations
data1 = np.random.normal(50, 5, 1000)   # Mean=50, Std Dev=5
data2 = np.random.normal(50, 15, 1000)  # Mean=50, Std Dev=15

# Calculate standard deviations
std_dev1 = np.std(data1)
std_dev2 = np.std(data2)

print(f"Standard Deviation of Dataset 1: {std_dev1:.2f}")
print(f"Standard Deviation of Dataset 2: {std_dev2:.2f}")

# Plot histograms
plt.hist(data1, bins=30, density=True, alpha=0.6, color='blue', label=f'Dataset 1 (Std Dev={std_dev1:.2f})')
plt.hist(data2, bins=30, density=True, alpha=0.6, color='red', label=f'Dataset 2 (Std Dev={std_dev2:.2f})')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Comparison of Standard Deviations')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Standard Deviation of Dataset 1: 4.90
# Standard Deviation of Dataset 2: 15.01

# %% [markdown]
# **22.Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution**

# %%
import numpy as np

# Generate data from a normal distribution
data = np.random.normal(loc=50, scale=10, size=1000)  # Mean=50, Std Dev=10

# Calculate Range
data_range = np.max(data) - np.min(data)

# Calculate Interquartile Range (IQR)
q1 = np.percentile(data, 25)  # First quartile (Q1)
q3 = np.percentile(data, 75)  # Third quartile (Q3)
iqr = q3 - q1  # IQR calculation

# Output results
print(f"Range: {data_range:.2f}")
print(f"Interquartile Range (IQR): {iqr:.2f}")
# Out:
# Range: 70.59
# Interquartile Range (IQR): 14.23

# %% [markdown]
# **23.Implement Z-score normalization on a dataset and visualize its transformation**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate a sample dataset
data = np.random.normal(50, 10, 1000)  # Mean=50, Std Dev=10

# Perform Z-score normalization
normalized_data = (data - np.mean(data)) / np.std(data)

# Plot histograms before and after normalization
plt.figure(figsize=(12, 5))

# Original Data Histogram
plt.subplot(1, 2, 1)
plt.hist(data, bins=30, density=True, color='lightcoral', edgecolor='black', alpha=0.7)
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Original Data Distribution')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Normalized Data Histogram
plt.subplot(1, 2, 2)
plt.hist(normalized_data, bins=30, density=True, color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel('Z-score')
plt.ylabel('Density')
plt.title('Z-score Normalized Distribution')
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# **24.Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal
# distribution.**

# %%
import numpy as np
import scipy.stats as stats

def compute_skewness_kurtosis(data):
    """Calculate skewness and kurtosis for a given dataset."""
    skewness = stats.skew(data)
    kurtosis = stats.kurtosis(data, fisher=True)  # Fisher=True gives excess kurtosis
    return skewness, kurtosis

# Generate data from a normal distribution
data = np.random.normal(loc=50, scale=10, size=1000)  # Mean=50, Std Dev=10

# Compute skewness and kurtosis
skewness, kurtosis = compute_skewness_kurtosis(data)

# Output results
print(f"Skewness: {skewness:.2f}")
print(f"Kurtosis (Excess): {kurtosis:.2f}")
# Out:
# Skewness: 0.03
# Kurtosis (Excess): -0.16

# %% [markdown]
# # Practical Part - 2

# %% [markdown]
# **1.Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and
# interpret the results**

# %%
import numpy as np
import scipy.stats as stats

# Sample dataset
data = np.random.normal(50, 10, 30)  # Mean=50, Std Dev=10, Sample size=30

# Hypothesis parameters
population_mean = 52  # Known population mean
sample_mean = np.mean(data)
sample_std_dev = np.std(data, ddof=1)  # Sample standard deviation
n = len(data)

# Compute Z-score
z_score = (sample_mean - population_mean) / (sample_std_dev / np.sqrt(n))

# Compute p-value for a two-tailed test
p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

# Output results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"Z-score: {z_score:.2f}")
print(f"P-value: {p_value:.5f}")

# Interpretation based on significance level
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis: There is enough evidence to support the alternative hypothesis.")
else:
    print("Fail to reject the null hypothesis: Not enough evidence to support the alternative hypothesis.")
# Out:
# Sample Mean: 49.20
# Z-score: -1.43
# P-value: 0.15369
# Fail to reject the null hypothesis: Not enough evidence to support the alternative hypothesis.

# %% [markdown]
# **2.Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python**

# %%
import numpy as np
import scipy.stats as stats

# Step 1: Generate random sample data
np.random.seed(42)  # For reproducibility
data = np.random.normal(loc=50, scale=10, size=30)  # Mean=50, Std Dev=10, Sample size=30

# Step 2: Define hypothesis parameters
population_mean = 52  # Hypothesized population mean
sample_mean = np.mean(data)
sample_std_dev = np.std(data, ddof=1)  # Sample standard deviation
n = len(data)

# Step 3: Compute Z-score
z_score = (sample_mean - population_mean) / (sample_std_dev / np.sqrt(n))

# Step 4: Compute p-value (two-tailed test)
p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

# Step 5: Output results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"Z-score: {z_score:.2f}")
print(f"P-value: {p_value:.5f}")

# Step 6: Decision based on significance level
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis: There is enough evidence to support the alternative hypothesis.")
else:
    print("Fail to reject the null hypothesis: Not enough evidence to support the alternative hypothesis.")
# Out:
# Sample Mean: 48.12
# Z-score: -2.36
# P-value: 0.01817
# Reject the null hypothesis: There is enough evidence to support the alternative hypothesis.

# %% [markdown]
# **3.Implement a one-sample Z-test using Python to compare the sample mean with the population meanE**

# %%
import numpy as np
import scipy.stats as stats

# Sample dataset
data = np.random.normal(loc=50, scale=10, size=30)  # Mean=50, Std Dev=10, Sample size=30

# Hypothesis parameters
population_mean = 52  # Known population mean
sample_mean = np.mean(data)
sample_std_dev = np.std(data, ddof=1)  # Sample standard deviation
n = len(data)

# Compute Z-score
z_score = (sample_mean - population_mean) / (sample_std_dev / np.sqrt(n))

# Compute p-value (two-tailed test)
p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

# Output results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"Z-score: {z_score:.2f}")
print(f"P-value: {p_value:.5f}")

# Interpretation based on significance level
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis: There is enough evidence to support the alternative hypothesis.")
else:
    print("Fail to reject the null hypothesis: Not enough evidence to support the alternative hypothesis.")
# Out:
# Sample Mean: 48.79
# Z-score: -1.89
# P-value: 0.05886
# Fail to reject the null hypothesis: Not enough evidence to support the alternative hypothesis.

# %% [markdown]
# **4.Perform a two-tailed Z-test using Python and visualize the decision region on a plot**

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Sample dataset
data = np.random.normal(loc=50, scale=10, size=30)  # Mean=50, Std Dev=10, Sample size=30

# Hypothesis parameters
population_mean = 52  # Hypothesized population mean
sample_mean = np.mean(data)
sample_std_dev = np.std(data, ddof=1)  # Sample standard deviation
n = len(data)

# Compute Z-score
z_score = (sample_mean - population_mean) / (sample_std_dev / np.sqrt(n))

# Compute p-value (two-tailed test)
p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

# Output results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"Z-score: {z_score:.2f}")
print(f"P-value: {p_value:.5f}")

# Decision rule
alpha = 0.05  # Significance level
z_critical = stats.norm.ppf(1 - alpha/2)  # Critical value for two-tailed test

if abs(z_score) > z_critical:
    print("Reject the null hypothesis: Significant difference detected.")
else:
    print("Fail to reject the null hypothesis: No significant difference.")

# Visualization of decision regions
x = np.linspace(-4, 4, 1000)
y = stats.norm.pdf(x, 0, 1)  # Standard normal distribution

plt.plot(x, y, color='skyblue', linewidth=2, label='Standard Normal Distribution')
plt.axvline(-z_critical, color='red', linestyle='--', label='Critical Value (-Z)')
plt.axvline(z_critical, color='red', linestyle='--', label='Critical Value (+Z)')
plt.axvline(z_score, color='black', linestyle='dotted', label=f'Z-score ({z_score:.2f})')
plt.fill_between(x, y, where=(x < -z_critical) | (x > z_critical), color='red', alpha=0.3, label='Rejection Region')
plt.xlabel('Z-score')
plt.ylabel('Probability Density')
plt.title('Two-Tailed Z-Test Decision Regions')
plt.legend()
plt.grid(linestyle='--', alpha=0.7)
plt.show()
# Out:
# Sample Mean: 50.13
# Z-score: -1.03
# P-value: 0.30153
# Fail to reject the null hypothesis: No significant difference.

# %% [markdown]
# **5.Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def visualize_errors(alpha=0.05, beta=0.2, mean_null=50, mean_alt=53, std_dev=10):
    """
    Visualizes Type 1 and Type 2 errors in hypothesis testing.

    Parameters:
    alpha (float)   : Significance level (Type 1 error probability)
    beta (float)    : Probability of Type 2 error
    mean_null (int) : Mean under null hypothesis (H0)
    mean_alt (int)  : Mean under alternative hypothesis (H1)
    std_dev (int)   : Standard deviation of both distributions
    """

    # Define x-axis range
    x = np.linspace(30, 70, 1000)

    # Compute normal distributions for H0 and H1
    pdf_null = norm.pdf(x, mean_null, std_dev)
    pdf_alt = norm.pdf(x, mean_alt, std_dev)

    # Compute critical value for Type 1 error (right-tailed)
    critical_value = norm.ppf(1 - alpha, mean_null, std_dev)

    # Plot both distributions
    plt.plot(x, pdf_null, label='Null Distribution (H0)', color='blue')
    plt.plot(x, pdf_alt, label='Alternative Distribution (H1)', color='red')

    # Shade Type 1 Error (Alpha)
    plt.fill_between(x, pdf_null, where=(x >= critical_value), color='blue', alpha=0.3, label='Type 1 Error (α)')

    # Shade Type 2 Error (Beta)
    plt.fill_between(x, pdf_alt, where=(x < critical_value), color='red', alpha=0.3, label='Type 2 Error (β)')

    # Labels and legend
    plt.axvline(critical_value, color='black', linestyle='--', label=f'Critical Value (α={alpha})')
    plt.xlabel('Test Statistic')
    plt.ylabel('Probability Density')
    plt.title('Type 1 & Type 2 Errors in Hypothesis Testing')
    plt.legend()
    plt.grid(linestyle='--', alpha=0.6)
    plt.show()

# Run the visualization function
visualize_errors()

# %% [markdown]
# **6.Write a Python program to perform an independent T-test and interpret the results**

# %%
import numpy as np
from scipy import stats

# Sample data (two independent groups)
group1 = np.array([22, 25, 29, 34, 30, 28, 21, 23, 27])
group2 = np.array([35, 40, 38, 45, 42, 39, 41, 43, 44])

# Perform the independent t-test
t_stat, p_value = stats.ttest_ind(group1, group2)

# Interpret results
alpha = 0.05  # Significance level
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between the two groups.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference between the two groups.")
# Out:
# T-statistic: -8.1035
# P-value: 0.0000
# Reject the null hypothesis: There is a significant difference between the two groups.

# %% [markdown]
# **7.Perform a paired sample T-test using Python and visualize the comparison results**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Sample data: Before and After measurements (paired samples)
before = np.array([22, 25, 29, 34, 30, 28, 21, 23, 27])
after = np.array([24, 26, 32, 36, 31, 30, 23, 25, 28])

# Perform the paired t-test
t_stat, p_value = stats.ttest_rel(before, after)

# Interpret results
alpha = 0.05  # Significance level
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between the paired groups.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference between the paired groups.")

# Visualization
plt.figure(figsize=(6, 4))
plt.plot(before, label="Before", marker="o")
plt.plot(after, label="After", marker="o")
plt.xlabel("Sample Index")
plt.ylabel("Values")
plt.title("Paired Sample Comparison")
plt.legend()
plt.show()
# Out:
# T-statistic: -8.0000
# P-value: 0.0000
# Reject the null hypothesis: There is a significant difference between the paired groups.

# %% [markdown]
# **8.Simulate data and perform both Z-test and T-test, then compare the results using Python**

# %%
import numpy as np
import scipy.stats as stats

# Simulating data: Two sample groups
np.random.seed(42)
group1 = np.random.normal(loc=50, scale=10, size=30)  # Mean = 50, Std Dev = 10
group2 = np.random.normal(loc=55, scale=10, size=30)  # Mean = 55, Std Dev = 10

# Perform an independent T-test
t_stat, t_p_value = stats.ttest_ind(group1, group2)

# Perform a Z-test (assuming population variance is known)
population_std = 10  # Known population standard deviation
z_stat = (np.mean(group1) - np.mean(group2)) / np.sqrt(population_std**2 / len(group1) + population_std**2 / len(group2))
z_p_value = stats.norm.sf(abs(z_stat)) * 2  # Two-tailed test

# Print results
print(f"T-test Results: T-statistic = {t_stat:.4f}, P-value = {t_p_value:.4f}")
print(f"Z-test Results: Z-statistic = {z_stat:.4f}, P-value = {z_p_value:.4f}")

# Interpretation
alpha = 0.05
if t_p_value < alpha:
    print("T-test: Reject the null hypothesis - Significant difference between groups.")
else:
    print("T-test: Fail to reject the null hypothesis - No significant difference.")

if z_p_value < alpha:
    print("Z-test: Reject the null hypothesis - Significant difference between groups.")
else:
    print("Z-test: Fail to reject the null hypothesis - No significant difference.")
# Out:
# T-test Results: T-statistic = -2.3981, P-value = 0.0197
# Z-test Results: Z-statistic = -2.1959, P-value = 0.0281
# T-test: Reject the null hypothesis - Significant difference between groups.
# Z-test: Reject the null hypothesis - Significant difference between groups.

# %% [markdown]
# **9.Write a Python function to calculate the confidence interval for a sample mean and explain its significance**

# %%
import numpy as np
import scipy.stats as stats

def confidence_interval(data, confidence=0.95):
    """
    Calculate the confidence interval for a sample mean.

    Parameters:
    - data: List or NumPy array of sample values
    - confidence: Confidence level (default is 95%)

    Returns:
    - Tuple containing (lower bound, upper bound)
    """
    sample_mean = np.mean(data)
    sample_std = np.std(data, ddof=1)  # Sample standard deviation
    n = len(data)

    # Use t-distribution for small samples, Z-distribution for large samples
    if n < 30:
        critical_value = stats.t.ppf((1 + confidence) / 2, df=n-1)
    else:
        critical_value = stats.norm.ppf((1 + confidence) / 2)

    margin_of_error = critical_value * (sample_std / np.sqrt(n))

    return sample_mean - margin_of_error, sample_mean + margin_of_error

# Example usage
sample_data = np.random.normal(loc=50, scale=10, size=25)  # Simulated sample
ci_lower, ci_upper = confidence_interval(sample_data)
print(f"95% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# 95% Confidence Interval: (45.50, 54.23)

# %% [markdown]
# **10.Write a Python program to calculate the margin of error for a given confidence level using sample data**

# %%
import numpy as np
import scipy.stats as stats

def margin_of_error(data, confidence=0.95):
    """
    Calculate the margin of error for a given confidence level.

    Parameters:
    - data: List or NumPy array of sample values
    - confidence: Confidence level (default is 95%)

    Returns:
    - Margin of error value
    """
    sample_mean = np.mean(data)
    sample_std = np.std(data, ddof=1)  # Sample standard deviation
    n = len(data)

    # Use t-distribution for small samples, Z-distribution for large samples
    if n < 30:
        critical_value = stats.t.ppf((1 + confidence) / 2, df=n-1)
    else:
        critical_value = stats.norm.ppf((1 + confidence) / 2)

    margin_of_error = critical_value * (sample_std / np.sqrt(n))

    return margin_of_error

# Example usage
sample_data = np.random.normal(loc=50, scale=10, size=25)  # Simulated sample
moe = margin_of_error(sample_data)
print(f"Margin of Error (95% Confidence): {moe:.2f}")
# Out:
# Margin of Error (95% Confidence): 2.98

# %% [markdown]
# **11. Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process**

# %%
def bayes_theorem(prior, likelihood, evidence):
    """
    Compute posterior probability using Bayes' Theorem.

    Parameters:
    - prior: P(H) - Initial belief (probability of disease before test)
    - likelihood: P(E|H) - Probability of a positive test given disease
    - evidence: P(E) - Overall probability of a positive test

    Returns:
    - Posterior probability P(H|E)
    """
    posterior = (likelihood * prior) / evidence
    return posterior

# Given data:
prior = 0.01  # 1% of people have the disease (P(H))
likelihood = 0.95  # 95% test sensitivity (P(E|H))
false_positive_rate = 0.05  # 5% false positive rate (P(E|¬H))

# Compute P(E): Total probability of testing positive
evidence = (likelihood * prior) + (false_positive_rate * (1 - prior))

# Calculate posterior probability
posterior = bayes_theorem(prior, likelihood, evidence)
print(f"Probability of having the disease given a positive test result: {posterior:.4f}")
# Out:
# Probability of having the disease given a positive test result: 0.1610

# %% [markdown]
# **12.Perform a Chi-square test for independence between two categorical variables in Python**

# %%
import numpy as np
import scipy.stats as stats
import pandas as pd

# Sample data: Contingency table (observed values)
data = np.array([[50, 30],   # Group A (Category 1 & 2)
                 [20, 40]])  # Group B (Category 1 & 2)

# Convert to Pandas DataFrame for better visualization
df = pd.DataFrame(data, columns=["Category 1", "Category 2"], index=["Group A", "Group B"])
print("Observed Data:\n", df)

# Perform the Chi-square test
chi2_stat, p_value, dof, expected = stats.chi2_contingency(data)

# Print results
print(f"\nChi-square Statistic: {chi2_stat:.4f}")
print(f"P-value: {p_value:.4f}")
print(f"Degrees of Freedom: {dof}")
print(f"Expected Frequencies:\n{pd.DataFrame(expected, columns=df.columns, index=df.index)}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("\nReject the null hypothesis: There is a significant association between the variables.")
else:
    print("\nFail to reject the null hypothesis: No significant association between the variables.")
# Out:
# Observed Data:
#           Category 1  Category 2
# Group A          50          30
# Group B          20          40
#
# Chi-square Statistic: 10.5292
# P-value: 0.0012
# Degrees of Freedom: 1
# Expected Frequencies:
#          Category 1  Category 2
# Group A        40.0        40.0
# Group B        30.0        30.0
#
# Reject the null hypothesis: There is a significant association between the variables.

# %% [markdown]
# **13.Write a Python program to calculate the expected frequencies for a Chi-square test based on observed
# data**

# %%
import numpy as np
import pandas as pd

def calculate_expected_frequencies(observed):
    """
    Compute expected frequencies for a Chi-square test.

    Parameters:
    - observed: 2D NumPy array or Pandas DataFrame containing observed values

    Returns:
    - Expected frequency table as a Pandas DataFrame
    """
    # Convert to NumPy array if input is a DataFrame
    observed = np.array(observed)

    # Compute row and column sums
    row_totals = observed.sum(axis=1, keepdims=True)
    col_totals = observed.sum(axis=0, keepdims=True)
    grand_total = observed.sum()

    # Calculate expected frequencies
    expected = (row_totals @ col_totals) / grand_total

    return pd.DataFrame(expected, columns=["Category 1", "Category 2"], index=["Group A", "Group B"])

# Example observed data (Contingency Table)
observed_data = np.array([[50, 30],  # Group A (Category 1 & 2)
                          [20, 40]]) # Group B (Category 1 & 2)

# Calculate expected frequencies
expected_frequencies = calculate_expected_frequencies(observed_data)

# Display results
print("Observed Data:\n", pd.DataFrame(observed_data, columns=["Category 1", "Category 2"], index=["Group A", "Group B"]))
print("\nExpected Frequencies:\n", expected_frequencies)
# Out:
# Observed Data:
#           Category 1  Category 2
# Group A          50          30
# Group B          20          40
#
# Expected Frequencies:
#           Category 1  Category 2
# Group A        40.0        40.0
# Group B        30.0        30.0

# %% [markdown]
# **14.Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution.**

# %%
import scipy.stats as stats
import numpy as np

# Observed data (actual counts)
observed = np.array([50, 30, 20])

# Automatically compute expected frequencies
expected = np.ones_like(observed) * observed.sum() / len(observed)  # Ensures sum matches

# Perform Chi-square goodness-of-fit test
chi2_stat, p_value = stats.chisquare(observed, expected)

print(f"Chi-square Statistic: {chi2_stat:.2f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
if p_value < 0.05:
    print("The observed distribution differs significantly from the expected one.")
else:
    print("The observed distribution matches the expected distribution.")
# Out:
# Chi-square Statistic: 14.00
# P-value: 0.0009
# The observed distribution differs significantly from the expected one.
